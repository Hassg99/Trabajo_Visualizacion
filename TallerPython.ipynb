# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None) #Mostrar todas las columnas

# %%
datos = pd.read_csv(r"C:\Users\hassg\OneDrive\Documents\GitHub\Trabajo_Visualizacion\datos.csv",
                   sep =";",
                   index_col = False,
                   error_bad_lines=False)

# %%
datos.head()
# Out:
#        ID  TARGET    CONTRACT_TYPE SEX  OWN_REALTY  CHILDREN  INCOME   CREDIT  \
# 0  100002       1       Cash loans   M           1         0  202500   406598
# 1  100003       0       Cash loans   F           0         0  270000  1293503
# 2  100004       0  Revolving loans   M           1         0   67500   135000
# 3  100006       0       Cash loans   F           1         0  135000   312683
# 4  100007       0       Cash loans   M           1         0  121500   513000
#
#      INCOME_TYPE                 EDUCATION_TYPE         FAMILY_STATUS  \
# 0        Working  Secondary / secondary special  Single / not married
# 1  State servant               Higher education               Married
# 2        Working  Secondary / secondary special  Single / not married
# 3        Working  Secondary / secondary special        Civil marriage
# 4        Working  Secondary / secondary special  Single / not married
#
#         HOUSING_TYPE  BIRTH EMPLOYED  EMP_PHONE  CONT_MOBILE  EMAIL  \
# 0  House / apartment     26        2          1            1      0
# 1  House / apartment     46        3          1            1      0
# 2  House / apartment     52        1          1            1      0
# 3  House / apartment     52        8          1            1      0
# 4  House / apartment     55        8          1            1      0
#
#   OCCUPATION_TYPE    WEEKDAY  REG_REGION_NOT_LIVE_REGION  DEF_30_CNT  \
# 0        Laborers  WEDNESDAY                           0         2.0
# 1      Core staff     MONDAY                           0         0.0
# 2        Laborers     MONDAY                           0         0.0
# 3        Laborers  WEDNESDAY                           0         0.0
# 4      Core staff   THURSDAY                           0         0.0
#
#    DEF_60_CNT  DAYS_LAST_PHONE_CHANGE  CREDIT_BUREAU_3meses
# 0         2.0                 -1134.0                   0.0
# 1         0.0                  -828.0                   0.0
# 2         0.0                  -815.0                   0.0
# 3         0.0                  -617.0                   NaN
# 4         0.0                 -1106.0                   0.0
